# %% [markdown]
# ### Run baseline methods

# %% [markdown]
# **Iterations**: currently running two iterations for reduction and rejection as they take relatively long. Other methods we set default -n 10.
#
# **Base model**: the default model is gbm; currently we're plotting against equalized odds on the x-axis.
#
# command to run: python3 benchmark.py -m [model name] -f [fair method] -c [constraint] -n [num iter] -i [inputfile] -s [seed]
#
# Options for arguments:
# - [model name]: gbm, logit, rf (Default: gbm)
# - [fair method]: reduction, eqodds, roc, ... (Default: reduction)
# - [constraint]: eo, sp, (Default: eo)
# - [num iter]: Any positive integer (Default: 10)
# - [inputfile]: hsls, enem-20000, enem-50000, adult, compas (Default: hsls)
# - [seed]: Any integer (Default: 42)

# %%
# !python run_benchmark_multiplicity_fair.py -m logit -f reduction -c eo -n 5 -i compas -s 25
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# #### Data Loaded.
# ## Epsilon =0.001
# Iteration # 0
# 0.3541666666666667
# Average odds difference:0.04757141254673353
# Overall Test Accuracy:0.6452020202020202
# Overall Test Multiplicity:0.3541666666666667
# Time per iteration:80.340163230896
# ----------------------------------------------------------
# Iteration # 1
# 0.3667929292929293
# Average odds difference:0.01321716028069253
# Overall Test Accuracy:0.6338383838383839
# Overall Test Multiplicity:0.3667929292929293
# Time per iteration:88.27707624435425
# ----------------------------------------------------------
# Iteration # 2
# 0.5429292929292929
# Average odds difference:0.017117062279092987
# Overall Test Accuracy:0.6275252525252525
# Overall Test Multiplicity:0.5429292929292929
# Time per iteration:91.19619703292847
# ----------------------------------------------------------
# ...

# %%
# !python run_benchmark_multiplicity_fair.py -m rf -f eqodds -c eo -n 8 -i hsls -s 25
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# #### Data Loaded.
# Iteration # 0
# Average odds difference:0.023412347240398035
# Overall Test Accuracy:0.6807533302710151
# Overall Test Multiplicity:0.7864033073036288
# Time per iteration:2.5663022994995117
# ----------------------------------------------------------
# Iteration # 1
# Average odds difference:0.01476103428185406
# Overall Test Accuracy:0.6825907211759302
# Overall Test Multiplicity:0.7703261368856225
# Time per iteration:2.5799570083618164
# ----------------------------------------------------------
# Iteration # 2
# Average odds difference:0.009415294435092592
# Overall Test Accuracy:0.692237023426734
# Overall Test Multiplicity:0.7519522278364722
# Time per iteration:2.5461831092834473
# ----------------------------------------------------------
# Iteration # 3
# Average odds difference:0.01281022986079608
# ...

# %%
# !python run_benchmark_multiplicity_fair.py -m rf -f reduction -c eo -n 8 -i hsls -s 25
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# #### Data Loaded.
# ## Epsilon =0.001
# Iteration # 0
# Average odds difference:0.10443389434478935
# Overall Test Accuracy:0.7397197335171146
# Overall Test Multiplicity:0.47507466115322766
# Time per iteration:249.24114990234375
# ----------------------------------------------------------
# Iteration # 1
# Average odds difference:0.07667225920134078
# Overall Test Accuracy:0.7236388697450035
# Overall Test Multiplicity:0.47691247415575466
# Time per iteration:264.69093894958496
# ----------------------------------------------------------
# Iteration # 2
# Average odds difference:0.0698596992200887
# Overall Test Accuracy:0.7410980932690099
# Overall Test Multiplicity:0.48495290604181024
# Time per iteration:262.1198568344116
# ----------------------------------------------------------
# Iteration # 3
# Average odds difference:0.06041543174516764
# ...

# %%
# !python run_benchmark_multiplicity_fair.py -m rf -f roc -c eo -n 8 -i hsls -s 25
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# #### Data Loaded.
# ## Epsilon =0.001
# Iteration # 0
# Optimal classification threshold (with fairness constraints) = 0.4555
# Optimal ROC margin = 0.0837
# Optimal classification threshold (with fairness constraints) = 0.3961
# Optimal ROC margin = 0.0808
# Optimal classification threshold (with fairness constraints) = 0.4357
# Optimal ROC margin = 0.0889
# Optimal classification threshold (with fairness constraints) = 0.4852
# Optimal ROC margin = 0.0792
# Optimal classification threshold (with fairness constraints) = 0.5148
# Optimal ROC margin = 0.0792
# Optimal classification threshold (with fairness constraints) = 0.3565
# Optimal ROC margin = 0.0582
# Optimal classification threshold (with fairness constraints) = 0.3466
# Optimal ROC margin = 0.0778
# Optimal classification threshold (with fairness constraints) = 0.4654
# ...

# %%
# !python run_benchmark_multiplicity_fair.py -m rf -f original -c eo -n 8 -i hsls -s 25
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# #### Data Loaded.
# Iteration # 0
# Average odds difference:0.19573509162809716
# Overall Test Accuracy:0.7360441075120606
# Overall Test Multiplicity:0.44589937973811167
# Time per iteration:2.2339651584625244
# ----------------------------------------------------------
# Iteration # 1
# Average odds difference:0.18610084336041016
# Overall Test Accuracy:0.7286928555019527
# Overall Test Multiplicity:0.44566965311279577
# Time per iteration:2.2279551029205322
# ----------------------------------------------------------
# Iteration # 2
# Average odds difference:0.1400608388003668
# Overall Test Accuracy:0.7394900068917988
# Overall Test Multiplicity:0.4426832069836894
# Time per iteration:2.181519031524658
# ----------------------------------------------------------
# Iteration # 3
# Average odds difference:0.16675444630856534
# ...

# %% [markdown]
# ## prev

# %%
# !python run_benchmark.py -f roc -i adult -m rf -n 1
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# 2023-02-22 09:30:32.887610: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# #### Data Loaded.
# ## Epsilon =0.005
# Iteration # 0
# Optimal classification threshold (with fairness constraints) = 0.2620
# Optimal ROC margin = 0.1142
# Max equalized odds:0.09296713455129302
# Overall Test Accuracy:0.8096024113678771
# Time per iteration:8.796079874038696
# ----------------------------------------------------------
# ## Epsilon =0.0075
# Iteration # 0
# Optimal classification threshold (with fairness constraints) = 0.2620
# Optimal ROC margin = 0.1142
# ...

# %%
# !python run_benchmark.py -f eqodds -i adult -m rf -n 1
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# 2023-02-22 09:31:14.630365: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# #### Data Loaded.
# Iteration # 0
# Max equalized odds:0.01700718334381701
# Overall Test Accuracy:0.8121860198076647
# Time per iteration:0.41534996032714844
# ----------------------------------------------------------

# %%
# !python run_benchmark.py -f caleqodds -i adult -m rf -n 1
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# 2023-02-22 09:31:20.175164: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# #### Data Loaded.
# Iteration # 0
# Max equalized odds:0.07257088643227255
# Overall Test Accuracy:0.823525190182288
# Time per iteration:0.44901299476623535
# ----------------------------------------------------------

# %%
# !python run_benchmark.py -f leveraging -i adult -m rf -n 1
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# 2023-02-22 09:31:25.784505: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# #### Data Loaded.
# 100%|█████████████████████████████████████████████| 1/1 [00:05<00:00,  5.28s/it]

# %%
#!python run_benchmark.py -f reduction -i compas_perturbed -m rf -n 10
#!python run_benchmark.py -f roc -i compas_perturbed -m rf -n 10
#!python run_benchmark.py -f eqodds -i compas_perturbed -m rf -n 10
# !python run_benchmark.py -f caleqodds -i compas_perturbed -m rf -n 10
#!python run_benchmark.py -f leveraging -i compas_perturbed -m rf -n 10
#!python run_benchmark.py -f original -i compas_perturbed -m rf -n 10
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# 2023-02-22 09:31:36.205089: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Invalid Input Dataset Name

# %%
#!python run_benchmark.py -f reduction -i adult_perturbed -m gbm -n 2
#!python run_benchmark.py -f roc -i adult_perturbed -m gbm -n 2 
#!python run_benchmark.py -f eqodds -i adult_perturbed -m gbm -n 10
#!python run_benchmark.py -f caleqodds -i adult_perturbed -m gbm -n 10
# !python run_benchmark.py -f leveraging -i adult_perturbed -m gbm -n 10
#!python run_benchmark.py -f original -i adult_perturbed -m  gbm -n 10
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# 2023-02-22 09:31:39.906833: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Invalid Input Dataset Name

# %% [markdown]
# ### Run Fair-Projection

# %%
# !python run-mp-sensitive.py -i adult -r 2
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# 2023-02-22 09:39:55.201016: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Users/carollong/Dropbox (Harvard University)/fairness_accuracy_frontier-main/benchmarks/DataLoader.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfTest)
# ...

# %%
# !python run-mp.py -i compas -r 10
# Out:
# ...
# 100%|██████████████████████████████████████████| 10/10 [24:48<00:00, 148.84s/it]

# %%
# !python run-mp.py -i adult -r 2
# Out:
# ...
# 100%|██████████████████████████████████████████| 10/10 [24:56<00:00, 149.66s/it]

# %%
cd baseline-methods
# Out:
# /Users/carollong/Desktop/Fair-Multiplicity-w-Projection/baseline-methods

# %%
# !python run_benchmark_multiplicity_fair.py -m rf -f roc -c eo -n 8 -i enem -s 25
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# #### Data Loaded.
# ## Epsilon =0.001
# Iteration # 0
# Optimal classification threshold (with fairness constraints) = 0.5247
# Optimal ROC margin = 0.0679
# Optimal classification threshold (with fairness constraints) = 0.5742
# Optimal ROC margin = 0.0695
# Optimal classification threshold (with fairness constraints) = 0.5841
# Optimal ROC margin = 0.0679
# Optimal classification threshold (with fairness constraints) = 0.7722
# Optimal ROC margin = 0.0790
# Optimal classification threshold (with fairness constraints) = 0.5346
# Optimal ROC margin = 0.0665
# Optimal classification threshold (with fairness constraints) = 0.6930
# Optimal ROC margin = 0.0752
# Optimal classification threshold (with fairness constraints) = 0.5247
# Optimal ROC margin = 0.0679
# Optimal classification threshold (with fairness constraints) = 0.5742
# ...

# %%
# !python run_benchmark.py -f original -i compas -m rf -n 1
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# 2023-01-19 23:54:52.998269: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# #### Data Loaded.
# Iteration # 0
# Max equalized odds:0.17668859487791055
# Overall Test Accuracy:0.7627889352027283
# Time per iteration:0.10922694206237793
# ----------------------------------------------------------

# %%
# !python run_benchmark.py -f reduction -i compas -m rf -n 1
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# 2023-01-19 23:56:07.091587: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# #### Data Loaded.
# ## Epsilon =0.001
# Iteration # 0
# after the else clause: [0 1]
# Max equalized odds:0.01722344807893872
# Overall Test Accuracy:0.7595680181887079
# Time per iteration:8.292384147644043
# ----------------------------------------------------------
# ## Epsilon =1
# Iteration # 0
# after the else clause: [0 1]
# Max equalized odds:0.020176918014367495
# Overall Test Accuracy:0.7586206896551724
# Time per iteration:8.32466197013855
# ----------------------------------------------------------
# ...
