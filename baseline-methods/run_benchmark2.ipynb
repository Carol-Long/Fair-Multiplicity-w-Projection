# %%
# !python run_benchmark_multiplicity_fair.py -m rf -f eqodds -c eo -n 8 -i enem -s 25
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# #### Data Loaded.
# Iteration # 0
# Average odds difference:0.018523539533053246
# Overall Test Accuracy:0.6282666666666666
# Overall Test Multiplicity:0.764
# Time per iteration:9.137208938598633
# ----------------------------------------------------------
# Iteration # 1
# Average odds difference:0.004521426014558488
# Overall Test Accuracy:0.6238666666666667
# Overall Test Multiplicity:0.7981333333333334
# Time per iteration:9.14753794670105
# ----------------------------------------------------------
# Iteration # 2
# Average odds difference:0.003008894800845291
# Overall Test Accuracy:0.6182666666666666
# Overall Test Multiplicity:0.7846666666666666
# Time per iteration:9.432546615600586
# ----------------------------------------------------------
# Iteration # 3
# Average odds difference:0.0018514698701561916
# ...

# %%
# !python run_benchmark_multiplicity_fair.py -m rf -f reduction -c eo -n 8 -i enem -s 25
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# #### Data Loaded.
# ## Epsilon =0.001
# Iteration # 0
# Average odds difference:0.04875544762687406
# Overall Test Accuracy:0.6511333333333333
# Overall Test Multiplicity:0.4838
# Time per iteration:927.5252132415771
# ----------------------------------------------------------
# Iteration # 1
# Average odds difference:0.0354718827934265
# Overall Test Accuracy:0.6555333333333333
# Overall Test Multiplicity:0.4932666666666667
# Time per iteration:912.5346639156342
# ----------------------------------------------------------
# Iteration # 2
# Average odds difference:0.048635435360817436
# Overall Test Accuracy:0.6542
# Overall Test Multiplicity:0.47933333333333333
# Time per iteration:901.5188341140747
# ----------------------------------------------------------
# Iteration # 3
# Average odds difference:0.0363239230712229
# ...

# %%
# !python run_benchmark_multiplicity_fair.py -m rf -f roc -c eo -n 8 -i enem -s 25

# %%
# !python run_benchmark_multiplicity_fair.py -m rf -f original -c eo -n 8 -i enem -s 25
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# #### Data Loaded.
# Iteration # 0
# Average odds difference:0.24277203939380262
# Overall Test Accuracy:0.663
# Overall Test Multiplicity:0.41186666666666666
# Time per iteration:7.709574222564697
# ----------------------------------------------------------
# Iteration # 1
# Average odds difference:0.27899577419430155
# Overall Test Accuracy:0.6652666666666667
# Overall Test Multiplicity:0.4208
# Time per iteration:7.404757022857666
# ----------------------------------------------------------
# Iteration # 2
# Average odds difference:0.26866383916693526
# Overall Test Accuracy:0.6578666666666667
# Overall Test Multiplicity:0.40913333333333335
# Time per iteration:7.18338680267334
# ----------------------------------------------------------
# Iteration # 3
# Average odds difference:0.2692331170558131
# Overall Test Accuracy:0.6650666666666667
# ...

# %%
cd baseline-methods
# Out:
# /Users/carollong/Desktop/Fair-Multiplicity-w-Projection/baseline-methods

# %%
# !python run_benchmark_multiplicity_fair.py -m rf -f roc -c eo -n 8 -i hsls -s 25
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# #### Data Loaded.
# ## Epsilon =0.001
# Iteration # 0
# Optimal classification threshold (with fairness constraints) = 0.4555
# Optimal ROC margin = 0.0837
# Optimal classification threshold (with fairness constraints) = 0.3961
# Optimal ROC margin = 0.0808
# Optimal classification threshold (with fairness constraints) = 0.4357
# Optimal ROC margin = 0.0889
# Optimal classification threshold (with fairness constraints) = 0.4852
# Optimal ROC margin = 0.0792
# Optimal classification threshold (with fairness constraints) = 0.5148
# Optimal ROC margin = 0.0792
# Optimal classification threshold (with fairness constraints) = 0.3565
# Optimal ROC margin = 0.0582
# Optimal classification threshold (with fairness constraints) = 0.3466
# Optimal ROC margin = 0.0778
# Optimal classification threshold (with fairness constraints) = 0.4654
# ...
