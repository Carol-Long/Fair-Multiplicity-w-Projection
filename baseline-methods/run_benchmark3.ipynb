# %%
# !python run_benchmark_multiplicity_fair.py -m rf -f eqodds -c eo -n 8 -i adult -s 25
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# #### Data Loaded.
# Iteration # 0
# Average odds difference:0.019599524794432215
# Overall Test Accuracy:0.8389781859931114
# Overall Test Multiplicity:0.3330941446613088
# Time per iteration:3.467050075531006
# ----------------------------------------------------------
# Iteration # 1
# Average odds difference:0.015649548773880168
# Overall Test Accuracy:0.8421354764638347
# Overall Test Multiplicity:0.3493111366245695
# Time per iteration:3.498906135559082
# ----------------------------------------------------------
# Iteration # 2
# Average odds difference:0.02063301611314156
# Overall Test Accuracy:0.8319460390355913
# Overall Test Multiplicity:0.3203214695752009
# Time per iteration:3.406812906265259
# ----------------------------------------------------------
# Iteration # 3
# Average odds difference:0.028106102280877794
# ...

# %%
# !python run_benchmark_multiplicity_fair.py -m rf -f reduction -c eo -n 8 -i adult -s 25
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# #### Data Loaded.
# ## Epsilon =0.001
# Iteration # 0
# Average odds difference:0.016556964485293514
# Overall Test Accuracy:0.852529601722282
# Overall Test Multiplicity:0.2197344815213491
# Time per iteration:684.6947019100189
# ----------------------------------------------------------
# Iteration # 1
# Average odds difference:0.01161598439786627
# Overall Test Accuracy:0.8576246860423394
# Overall Test Multiplicity:0.18772874058127018
# Time per iteration:714.0111799240112
# ----------------------------------------------------------
# Iteration # 2
# Average odds difference:0.023197483020324126
# Overall Test Accuracy:0.8474345174022246
# Overall Test Multiplicity:0.20078937926085397
# Time per iteration:696.367091178894
# ----------------------------------------------------------
# Iteration # 3
# Average odds difference:0.02422669148471122
# ...

# %%
# !python run_benchmark_multiplicity_fair.py -m rf -f roc -c eo -n 8 -i adult -s 25
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# #### Data Loaded.
# ## Epsilon =0.001
# Iteration # 0
# Optimal classification threshold (with fairness constraints) = 0.2278
# Optimal ROC margin = 0.1209
# Optimal classification threshold (with fairness constraints) = 0.1882
# Optimal ROC margin = 0.1191
# Optimal classification threshold (with fairness constraints) = 0.3763
# Optimal ROC margin = 0.0691
# Optimal classification threshold (with fairness constraints) = 0.1882
# Optimal ROC margin = 0.1344
# Optimal classification threshold (with fairness constraints) = 0.2080
# Optimal ROC margin = 0.1231
# Optimal classification threshold (with fairness constraints) = 0.2773
# Optimal ROC margin = 0.0849
# Optimal classification threshold (with fairness constraints) = 0.1882
# Optimal ROC margin = 0.1114
# Optimal classification threshold (with fairness constraints) = 0.2773
# ...

# %%
# !python run_benchmark_multiplicity_fair.py -m rf -f original -c eo -n 8 -i adult -s 25
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# #### Data Loaded.
# Iteration # 0
# Average odds difference:0.05738990231192789
# Overall Test Accuracy:0.8574094007893792
# Overall Test Multiplicity:0.0736275565123789
# Time per iteration:2.9024901390075684
# ----------------------------------------------------------
# Iteration # 1
# Average odds difference:0.06744531172194851
# Overall Test Accuracy:0.8618586293505561
# Overall Test Multiplicity:0.07104413347685684
# Time per iteration:2.9300637245178223
# ----------------------------------------------------------
# Iteration # 2
# Average odds difference:0.0607454243316933
# Overall Test Accuracy:0.8528884104772156
# Overall Test Multiplicity:0.06874775744528167
# Time per iteration:2.8983590602874756
# ----------------------------------------------------------
# Iteration # 3
# Average odds difference:0.06523580121887454
# ...
